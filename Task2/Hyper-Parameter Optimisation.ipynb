# %%
#importing the necessary libs

import pandas as pd
import numpy as np

from sklearn.svm import SVC
from sklearn.model_selection import train_test_split

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#read the csv document and view the first 10 rows of the dataframe

date_cols = ['Admission Date',  'Discharge Date', 'Enrolment Date']
df = pd.read_csv(r'Claims Data _RSBY Gujarat cluster 2 Date Formatted.csv', parse_dates=date_cols, infer_datetime_format=True)
df.head(10)
# Out:
#             URN Unique Claim no.                     HOF Name  Patient Age  \
# 0  2.410000e+16           GBIC-1                 MRS.DAYABHAI           12
# 1  2.410000e+16           GBIC-2                    SARBAIBEN           80
# 2  2.420000e+16           GBIC-3                   BHAVINBHAI           32
# 3  2.420000e+16           GBIC-4  THAKOR PRATAPBHAI HEMTABHAI           70
# 4  2.420000e+16           GBIC-6  THAKOR PRATAPBHAI HEMTABHAI           18
# 5  2.420000e+16           GBIC-7                    MADHABHAI           70
# 6  2.420000e+16           GBIC-8                     MADUKHAN           30
# 7  2.410000e+16           GBIC-9                    NATHABHAI           52
# 8  2.410000e+16          GBIC-10                    NATHABHAI           52
# 9  2.410000e+16          GBIC-11                    NATHABHAI           52
#
#    Patient Card Gender  Member ID Beneficiary District Name  \
# 0                    1        2.0             Surendranagar
# 1                    2        1.0             Surendranagar
# 2                    1        1.0                     Anand
# 3                    1        1.0                     Kheda
# 4                    2        1.0                     Kheda
# 5                    2        1.0                     Anand
# 6                    2        1.0                     Kheda
# 7                    2        1.0             Surendranagar
# 8                    2        1.0             Surendranagar
# 9                    2        1.0             Surendranagar
#
#                Hospital Name Hospital Location/district Admission Date  \
# 0  Pt Deendayal Upadhyay Hos                     Rajkot     2016-05-24
# 1  Pt Deendayal Upadhyay Hos                     Rajkot     2016-05-24
# 2   Urja Orthopedic Hospital                   Vadodara     2016-05-27
# 3    Sagar Surgical Hospital                      Kheda     2016-05-27
# 4    Sagar Surgical Hospital                      Kheda     2016-05-27
# 5   Advanced Eye Care Clinic                   Vadodara     2016-06-03
# 6            Dhiraj Hospital                   Vadodara     2016-05-20
# 7  shradhdha surgical hospit                     Rajkot     2016-05-30
# 8  shradhdha surgical hospit                     Rajkot     2016-05-30
# 9  shradhdha surgical hospit                     Rajkot     2016-05-30
#
#   Discharge Date                                       Package Name  \
# 0     2016-05-30                          General Ward :Unspecified
# 1     2016-05-25                          General Ward :Unspecified
# 2     2016-06-01                          General Ward :Unspecified
# 3     2016-06-02                          General Ward :Unspecified
# 4     2016-06-02                          General Ward :Unspecified
# 5     2016-06-03  Cataract with foldable IOL by Phoco emulsifica...
# 6     2016-06-03                          Spine - Intradural Tumour
# 7     2016-06-04                             Salphingo-oophorectomy
# 8     2016-06-04                        Cystocele - Anterior repair
# 9     2016-06-04                          Hysterectomy - abdominal*
#
#    Claimed Amount  Approved Amount  Status Enrolment Type Enrolment Date
# 0            4500             4500    Paid        Renewal     2016-01-04
# 1             750              750    Paid        Renewal     2016-01-04
# 2            3750             3750    Paid        Renewal     2016-01-04
# 3            4500                0  Denied        Renewal     2016-01-04
# 4            4500                0  Denied        Renewal     2016-01-04
# 5            6000             6000    Paid        Renewal     2016-01-04
# 6           15400            15400    Paid        Renewal     2016-01-04
# 7            7875             6500    Paid        Renewal     2016-01-04
# 8            5750                0  Denied        Renewal     2016-01-04
# 9           11500            11500    Paid        Renewal     2016-01-04

# %%
#show all the col type
df.dtypes
# Out:
# URN                                  float64
# Unique Claim no.                      object
# HOF Name                              object
# Patient Age                            int64
# Patient Card Gender                    int64
# Member ID                            float64
# Beneficiary District Name             object
# Hospital Name                         object
# Hospital Location/district            object
# Admission Date                datetime64[ns]
# Discharge Date                datetime64[ns]
# Package Name                          object
# Claimed Amount                         int64
# Approved Amount                        int64
# Status                                object
# Enrolment Type                        object
# Enrolment Date                datetime64[ns]
# dtype: object

# %%
#view the infomation of the dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10446 entries, 0 to 10445
# Data columns (total 17 columns):
# URN                           10446 non-null float64
# Unique Claim no.              10446 non-null object
# HOF Name                      10446 non-null object
# Patient Age                   10446 non-null int64
# Patient Card Gender           10446 non-null int64
# Member ID                     10443 non-null float64
# Beneficiary District Name     10446 non-null object
# Hospital Name                 10446 non-null object
# Hospital Location/district    10446 non-null object
# Admission Date                10446 non-null datetime64[ns]
# Discharge Date                10446 non-null datetime64[ns]
# Package Name                  10445 non-null object
# Claimed Amount                10446 non-null int64
# Approved Amount               10446 non-null int64
# Status                        10446 non-null object
# Enrolment Type                10446 non-null object
# Enrolment Date                10446 non-null datetime64[ns]
# dtypes: datetime64[ns](3), float64(2), int64(4), object(8)
# memory usage: 1.4+ MB

# %%
#function to replace categorical variables with nominal variable
def recoding(col, codeDict):
  colCoded = pd.Series(col, copy=True)
  for key, value in codeDict.items():
    colCoded.replace(key, value, inplace=True)
  return colCoded

# %%
#function to convert all string cells to uppercase
headers = list(df)
str_header = []
for header in headers:
   if df[header].dtype == object:
    str_header.append(header) 
    df[header] = df[header].str.upper()
    df[header] = df[header].str.strip()

# %%
#recoding Status from categorical to nominal
df['Status (Coded)'] = recoding(df['Status'], {'PAID':1, 'DENIED': 0})

#checking
print (pd.value_counts(df['Status']))
print (pd.value_counts(df['Status (Coded)']))
# Out:
# PAID      9515
# DENIED     931
# Name: Status, dtype: int64
# 1    9515
# 0     931
# Name: Status (Coded), dtype: int64

# %%
#recoding Enrolment Type from categorical to nominal
df['Enrolment Type (Coded)'] = recoding(df['Enrolment Type'], {'RENEWAL': 1, 'FRESH': 2})

#checking
print (pd.value_counts(df['Enrolment Type']))
print (pd.value_counts(df['Enrolment Type (Coded)']))
# Out:
# RENEWAL    7088
# FRESH      3358
# Name: Enrolment Type, dtype: int64
# 1    7088
# 2    3358
# Name: Enrolment Type (Coded), dtype: int64

# %%
#creating a dataframe of only numerical variables
num_df = df.select_dtypes(include=[np.number]).copy().dropna(axis=0)
num_df
# Out:
#                 URN  Patient Age  Patient Card Gender  Member ID  \
# 0      2.410000e+16           12                    1        2.0
# 1      2.410000e+16           80                    2        1.0
# 2      2.420000e+16           32                    1        1.0
# 3      2.420000e+16           70                    1        1.0
# 4      2.420000e+16           18                    2        1.0
# 5      2.420000e+16           70                    2        1.0
# 6      2.420000e+16           30                    2        1.0
# 7      2.410000e+16           52                    2        1.0
# 8      2.410000e+16           52                    2        1.0
# 9      2.410000e+16           52                    2        1.0
# 10     2.420000e+16           22                    1        1.0
# 11     2.420000e+16           16                    1        1.0
# 12     2.420000e+16           70                    2        1.0
# 13     2.410000e+16           66                    1        1.0
# 14     2.420000e+16           45                    2        1.0
# 15     2.420000e+16           48                    1        1.0
# 16     2.420000e+16           48                    1        1.0
# 17     2.420000e+16           75                    1        1.0
# 18     2.420000e+16           75                    1        1.0
# 19     2.420000e+16           50                    1        1.0
# 20     2.420000e+16           60                    2        2.0
# 21     2.410000e+16           55                    2        1.0
# 22     2.420000e+16           40                    1        1.0
# 23     2.420000e+16           45                    2        2.0
# 24     2.410000e+16           22                    1        1.0
# 25     2.420000e+16           50                    1        1.0
# 26     2.420000e+16           30                    1        1.0
# 27     2.420000e+16           40                    1        1.0
# 28     2.420000e+16           41                    2        1.0
# 29     2.420000e+16           50                    1        1.0
# ...             ...          ...                  ...        ...
# 10416  2.420000e+16           42                    1        1.0
# 10417  2.420000e+16           35                    2        1.0
# 10418  2.410000e+16           60                    1        1.0
# 10419  2.410000e+16           35                    2        1.0
# 10420  2.410000e+16           35                    2        1.0
# 10421  2.420000e+16           60                    1        1.0
# 10422  2.420000e+16            1                    1        1.0
# 10423  2.410000e+16           70                    2        1.0
# 10424  2.410000e+16           52                    1        1.0
# 10425  2.420000e+16           42                    1        1.0
# 10426  2.410000e+16           30                    2        1.0
# 10427  2.410000e+16           18                    1        1.0
# 10428  2.420000e+16           28                    2        1.0
# 10429  2.410000e+16           45                    2        1.0
# 10430  2.410000e+16           20                    1        1.0
# 10431  2.410000e+16           65                    1        1.0
# 10432  2.420000e+16           40                    1        1.0
# 10433  2.420000e+16           40                    1        1.0
# 10434  2.410000e+16           36                    2        1.0
# 10435  2.420000e+16           45                    1        1.0
# 10436  2.420000e+16           21                    2        1.0
# 10437  2.420000e+16           55                    1        1.0
# 10438  2.420000e+16           40                    2        1.0
# 10439  2.410000e+16           21                    2        1.0
# 10440  2.410000e+16           21                    2        1.0
# 10441  2.420000e+16           60                    2        1.0
# 10442  2.420000e+16           60                    2        1.0
# 10443  2.410000e+16           35                    1        1.0
# 10444  2.410000e+16           45                    2        1.0
# 10445  2.420000e+16           45                    1        2.0
#
#        Claimed Amount  Approved Amount  Status (Coded)  Enrolment Type (Coded)
# 0                4500             4500               1                       1
# 1                 750              750               1                       1
# 2                3750             3750               1                       1
# 3                4500                0               0                       1
# 4                4500                0               0                       1
# 5                6000             6000               1                       1
# 6               15400            15400               1                       1
# 7                7875             6500               1                       1
# 8                5750                0               0                       1
# 9               11500            11500               1                       1
# 10               4500                0               0                       1
# 11               4500                0               0                       1
# 12               6000             6000               1                       1
# 13              12000            12000               1                       1
# 14              13750                0               0                       1
# 15               5625                0               0                       1
# 16              10500                0               0                       1
# 17               4000                0               0                       1
# 18               1125                0               0                       1
# 19               3750                0               0                       1
# 20               3000             3000               1                       1
# 21               6000             6000               1                       1
# 22               4500                0               0                       1
# 23               3000             3000               1                       1
# 24               5000             5000               1                       1
# 25               2250                0               0                       1
# 26               2250                0               0                       1
# 27               6750                0               0                       1
# 28              17500            17500               1                       1
# 29               5250                0               0                       1
# ...               ...              ...             ...                     ...
# 10416           17500            17500               1                       1
# 10417           11500            11500               1                       1
# 10418            6000             6000               1                       2
# 10419            2250             2250               1                       2
# 10420            2250             2250               1                       1
# 10421           12500            12500               1                       2
# 10422           12000            12000               1                       1
# 10423           22000            22000               1                       1
# 10424            6000             6000               1                       2
# 10425           16000                0               0                       1
# 10426            9500             9500               1                       2
# 10427            4500             4500               1                       1
# 10428            7500             6900               1                       2
# 10429           11500            11500               1                       2
# 10430           11900            11900               1                       2
# 10431            6182             6182               1                       1
# 10432           10500            10500               1                       1
# 10433           11250             7350               1                       1
# 10434           11500            11500               1                       2
# 10435             600              600               1                       2
# 10436            7500                0               0                       2
# 10437            7000             7000               1                       1
# 10438           22000            18000               1                       2
# 10439           18700            18700               1                       1
# 10440            6750             6750               1                       1
# 10441            2750                0               0                       1
# 10442           13750            11500               1                       1
# 10443           18000            18000               1                       2
# 10444           13000            13000               1                       1
# 10445           14250            14250               1                       2
#
# [10443 rows x 8 columns]

# %%
num_df.columns.get_loc('Status (Coded)')
# Out:
# 6

# %%
#splitting the dataframe into the X and Y components
y = num_df.iloc[:, 6]
x = num_df.drop(['URN', 'Status (Coded)'], axis=1)

X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.33)

# %%
#running the random hyper parameter optimisation
best_score = 0  
best_params = {'C': None, 'gamma': None}

#for 100 iterations seek best params
for i in range(100):
    #try random values for each hyperparameter
    c_ran = np.random.uniform(0.001, 100)
    gamma_ran = np.random.randint(0.001, 100)
    svc = SVC(C=c_ran, gamma=gamma_ran)
    svc.fit(X_train, y_train)
    score = svc.score(X_test, y_test)

    if score > best_score:
        best_score = score
        best_params['C'] = c_ran
        best_params['gamma'] = gamma_ran

best_score, best_params
# Out:
# (0.9370467072816943, {'C': 17.407592514188444, 'gamma': 1})
